# %% [markdown]
# <a href="https://colab.research.google.com/github/Repocr/Code-Decode-tool/blob/master/exportando_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos = pd.read_csv('superstore_data.csv')

# %%
datos.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
datos2 = pd.read_csv('superstore_data_punto_coma.csv')

# %%
datos2.head()
# Out:
#   Id;Year_Birth;Education;Marital_Status;Income;Kidhome;Teenhome;Dt_Customer;Recency;MntWines;MntFruits;MntMeatProducts;MntFishProducts;MntSweetProducts;MntGoldProds;NumDealsPurchases;NumWebPurchases;NumCatalogPurchases;NumStorePurchases;NumWebVisitsMonth;Response;Complain
# 0  1826;1970;Graduation;Divorced;84835;0;0;6/16/2...
# 1  1;1961;Graduation;Single;57091;0;0;6/15/2014;0...
# 2  10476;1958;Graduation;Married;67267;0;1;5/13/2...
# 3  1386;1967;Graduation;Together;32474;1;1;11/5/2...
# 4  5371;1989;Graduation;Single;21474;1;0;8/4/2014...

# %%
import pandas as pd
df = pd.read_csv('datos.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3830716559.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('datos.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import chardet

# %%
with open('datos.csv', 'rb') as file:
    print(chardet.detect(file.read()))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2604573786.py in <cell line: 0>()
# ----> 1 with open('datos.csv', 'rb') as file:
#       2     print(chardet.detect(file.read()))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datos.csv'

# %%
{'encoding': 'UTF-16', 'confidence': 1.0, 'language': ''}
# Out:
# {'encoding': 'UTF-16', 'confidence': 1.0, 'language': ''}

# %%
df = pd.read_csv('datos.csv', encoding='UTF-16')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2859098620.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('datos.csv', encoding='UTF-16')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
datos2 = pd.read_csv('superstore_data_punto_coma.csv')

# %%
datos2.head()
# Out:
#   Id;Year_Birth;Education;Marital_Status;Income;Kidhome;Teenhome;Dt_Customer;Recency;MntWines;MntFruits;MntMeatProducts;MntFishProducts;MntSweetProducts;MntGoldProds;NumDealsPurchases;NumWebPurchases;NumCatalogPurchases;NumStorePurchases;NumWebVisitsMonth;Response;Complain
# 0  1826;1970;Graduation;Divorced;84835;0;0;6/16/2...
# 1  1;1961;Graduation;Single;57091;0;0;6/15/2014;0...
# 2  10476;1958;Graduation;Married;67267;0;1;5/13/2...
# 3  1386;1967;Graduation;Together;32474;1;1;11/5/2...
# 4  5371;1989;Graduation;Single;21474;1;0;8/4/2014...

# %%
datos2.
# Out:
#   File "/tmp/ipython-input-734270594.py", line 1
#     datos2.
#            ^
# SyntaxError: invalid syntax

# %%
datos2.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
datos2 = pd.read_csv('superstore_data_punto_coma.csv',sep=';')

# %%
datos2 = pd.read_csv('superstore_data_punto_coma.csv',nrows= 5)

# %%
datos2
# Out:
#   Id;Year_Birth;Education;Marital_Status;Income;Kidhome;Teenhome;Dt_Customer;Recency;MntWines;MntFruits;MntMeatProducts;MntFishProducts;MntSweetProducts;MntGoldProds;NumDealsPurchases;NumWebPurchases;NumCatalogPurchases;NumStorePurchases;NumWebVisitsMonth;Response;Complain
# 0  1826;1970;Graduation;Divorced;84835;0;0;6/16/2...
# 1  1;1961;Graduation;Single;57091;0;0;6/15/2014;0...
# 2  10476;1958;Graduation;Married;67267;0;1;5/13/2...
# 3  1386;1967;Graduation;Together;32474;1;1;11/5/2...
# 4  5371;1989;Graduation;Single;21474;1;0;8/4/2014...

# %%
datos = pd.read_csv('superstore_data.csv')

# %%
datos = pd.read_csv('superstore_data.csv',nrows= 10)

# %%
datos
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
# 5   7348        1958         PhD         Single   71691        0         0
# 6   4073        1954    2n Cycle        Married   63564        0         0
# 7   1991        1967  Graduation       Together   44931        0         1
# 8   4047        1954         PhD        Married   65324        0         1
# 9   9477        1954         PhD        Married   65324        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# ...

# %%
datos = pd.read_csv('superstore_data.csv',usecols= 3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2822006952.py in <cell line: 0>()
# ----> 1 datos = pd.read_csv('superstore_data.csv',usecols= 3)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
datos_selection  = pd.read_csv('superstore_data.csv',usecols=['Id','Year_Birth','Income'])

# %%
datos_selection
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
datos_selection  = pd.read_csv('superstore_data.csv',usecols=[0,1,4])

# %%
datos_selection
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
datos_selection.to_csv('Clientes_mercado.csv')

# %%
clientes_mercado = pd.read_csv('Clientes_mercado.csv')

# %%
clientes_mercado
# Out:
#       Unnamed: 0     Id  Year_Birth   Income
# 0              0   1826        1970  84835.0
# 1              1      1        1961  57091.0
# 2              2  10476        1958  67267.0
# 3              3   1386        1967  32474.0
# 4              4   5371        1989  21474.0
# ...          ...    ...         ...      ...
# 2235        2235  10142        1976  66476.0
# 2236        2236   5263        1977  31056.0
# 2237        2237     22        1976  46310.0
# 2238        2238    528        1978  65819.0
# 2239        2239   4070        1969  94871.0
#
# [2240 rows x 4 columns]

# %%
datos_selection.to_csv('datos_mercado.csv',index=False)

# %%
datos_mercado=pd.read_csv('datos_mercado.csv')

# %%
datos_mercado
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]
