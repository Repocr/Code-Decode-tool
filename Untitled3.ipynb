# %% [markdown]
# <a href="https://colab.research.google.com/github/Repocr/Code-Decode-tool/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos_html = pd.read_html('peliculas_wikipedia.html')

# %%
datos_html
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                              Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
# ...

# %%
type(datos_html)
# Out:
# list

# %%
len(datos_html)
# Out:
# 3

# %%
datos_html[1]
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %%
top_peliculas = datos_html[1]

# %%
top_peliculas
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %%
top_peliculas.to_html('tp _peliculas.html')

# %%
pd.read_html('tp _peliculas.html')
# Out:
# [    Unnamed: 0                          Film  Release year  \
#  0            0                  Citizen Kane          1941
#  1            1                    Casablanca          1942
#  2            2                 The Godfather          1972
#  3            3            Gone with the Wind          1939
#  4            4            Lawrence of Arabia          1962
#  ..         ...                           ...           ...
#  95          95                 The Searchers          1956
#  96          96              Bringing Up Baby          1938
#  97          97                    Unforgiven          1992
#  98          98  Guess Who's Coming to Dinner          1967
#  99          99           Yankee Doodle Dandy          1942
#
#                  Director                    Production companies  Rank
#  0           Orson Welles                      RKO Radio Pictures     1
#  1         Michael Curtiz                   Warner Bros. Pictures     2
# ...

# %%
top_peliculas.to_csv('top_peliculas.csv')

# %%
datos =pd.read_csv('top_peliculas.csv')

# %%
datos.head()
# Out:
#    Unnamed: 0                Film  Release year              Director  \
# 0           0        Citizen Kane          1941          Orson Welles
# 1           1          Casablanca          1942        Michael Curtiz
# 2           2       The Godfather          1972  Francis Ford Coppola
# 3           3  Gone with the Wind          1939        Victor Fleming
# 4           4  Lawrence of Arabia          1962            David Lean
#
#                      Production companies  Rank
# 0                      RKO Radio Pictures     1
# 1                   Warner Bros. Pictures     2
# 2  Paramount Pictures, Alfran Productions     3
# 3         Selznick International Pictures     4
# 4                        Horizon Pictures     5

# %%
import pandas as pd

# %%
pd.read_xml ('imdb_top_1000.xml')
# Out:
#      index                                        Poster_Link  \
# 0        0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1        1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2        2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3        3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4        4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..     ...                                                ...
# 995    995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996    996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997    997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998    998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999    999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# ...

# %%
datos.head(3)
# Out:
#    Unnamed: 0           Film  Release year              Director  \
# 0           0   Citizen Kane          1941          Orson Welles
# 1           1     Casablanca          1942        Michael Curtiz
# 2           2  The Godfather          1972  Francis Ford Coppola
#
#                      Production companies  Rank
# 0                      RKO Radio Pictures     1
# 1                   Warner Bros. Pictures     2
# 2  Paramount Pictures, Alfran Productions     3

# %%
# This appears to be XML code, not Python.
# If you want to process XML in Python, you'd use libraries like xml.etree.ElementTree.
# Here's an example of how you might parse this XML:

import xml.etree.ElementTree as ET

xml_string = """<?xml version="1.0" encoding="UTF-8"?>
<animales>
  <animal nombre="Mel" tipo="perro" color="marron"/>
</animales>"""

root = ET.fromstring(xml_string)
for animal in root.findall('animal'):
    nombre = animal.get('nombre')
    tipo = animal.get('tipo')
    color = animal.get('color')
    print(f"Animal: {nombre}, Tipo: {tipo}, Color: {color}")
  <animal nombre="Vick" tipo="gato" color="blanco"/>
</animales>
# Out:
#   File "<tokenize>", line 18
#     <animal nombre="Vick" tipo="gato" color="blanco"/>
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
pd.read_html('https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n')[0]
# Out:
#      N.º                   País (o territorio dependiente)  \
# 0      1                                             India
# 1      2                                        China[12]​
# 2      3                                    Estados Unidos
# 3      4                                         Indonesia
# 4      5                                          Pakistán
# ..   ...                                               ...
# 241  242                           Islas Cocos (Australia)
# 242  243  Islas Ultramarinas Menores de los Estados Unidos
# 243  244                               Islas Pitcairn (RU)
# 244  NaN                                             Mundo
# 245   N°                   País (o territorio dependiente)
#
#     Proyección exponencial de la población al 1/1/2025[7]​  \
# 0                                        1 411 278 000
# 1                                        1 407 582 000
# 2                                          337 642 000
# ...
